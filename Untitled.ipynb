# %% [markdown]
# ## Scrappi https://amarillas.emol.com/abogados/todo-chile

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import os

# %%
import time
# Configura la ruta para el controlador de Chrome
chromedriver = "D:/Web Scrapping/2/chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver

# Inicializa el controlador de Chrome
driver = webdriver.Chrome(chromedriver)

# Abre la URL deseada en el navegador
driver.get("https://amarillas.emol.com/abogados")
time.sleep(5)
html = driver.page_source

# Parsea el HTML con BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_34600\3132221965.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# <html class="ng-scope" id="ng-app" lang="es" ng-app="amarillas" xmlns:ng="https://angularjs.org"><head><style type="text/css">@charset "UTF-8";[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}</style>
# <!-- Google Tag Manager -->
# ...

# %%
# Crea un DataFrame vacío para guardar los títulos de los empleos
df = pd.DataFrame()

# Bucle para navegar por las páginas
inte=0
while inte<5:
    inte=inte+1
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    book_url_tag = soup.find_all('a', {"span",{"class":"ng-binding"}})
    print(book_url_tag)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


URL = "https://amarillas.emol.com/abogados"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
print(soup)
book_url_tag = soup.find_all("span", {"itemprop": "name", "class": "ng-binding"})
for i in book_url_tag:
    print(i)
    
df = pd.DataFrame(book_url_tag, columns=["Títulos de empleo"])

for tag in book_url_tag:
    df = df.append({ "Títulos de empleo": tag.text }, ignore_index=True)
    print(tag.text)


df.to_excel("resultados_.xlsx", index=False)
# Out:
# <!DOCTYPE html>
#
# <html id="ng-app" lang="es" ng-app="amarillas" xmlns:ng="https://angularjs.org">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 	})(window,document,'script','dataLayer','GTM-MMXMSRM');</script>
# <!-- End Google Tag Manager -->
# <!--[if lte IE 8]>
#       <script>
#         document.createElement('ng-include');
#         document.createElement('ng-pluralize');
#         document.createElement('ng-view');
#
#         // Optionally these for CSS
#         document.createElement('ng:include');
#         document.createElement('ng:pluralize');
#         document.createElement('ng:view');
#       </script>
#     <![endif]-->
# ...

# %%
import requests

url = "https://amarillas.emol.com/abogados"
response = requests.get(url)
print(response.headers)
# Out:
# {'Date': 'Fri, 03 Feb 2023 22:55:49 GMT', 'Server': 'Apache', 'Last-Modified': 'Tue, 15 Nov 2022 12:17:56 GMT', 'ETag': '"380eb4-30ba-5ed815890c500"', 'Accept-Ranges': 'bytes', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Length': '4054', 'Connection': 'close', 'Content-Type': 'text/html; charset=UTF-8'}

# %%
import time
# Configura la ruta para el controlador de Chrome
chromedriver = "D:/Web Scrapping/2/chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver

# Inicializa el controlador de Chrome


def download_html_ct(pagina):
    driver = webdriver.Chrome(chromedriver)
    driver.get("https://amarillas.emol.com/abogados?p={}".format(pagina))
    time.sleep(5)
    with open(r'offer{}.html'.format(pagina), 'w', encoding="utf-8") as f:
        f.write(driver.page_source)
    driver.quit()
try: 
    for i in range (3):
        download_html_ct(i)      
except:
    pass
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_34600\3008313017.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

url = "D:\Web_Scrapping\Prueba\offer1.html"
df = pd.DataFrame(columns=["Nombre","Direccion"])

with open(url, encoding="utf-8") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    section = soup.find("section", {"class": "template-search show-results col_main"})
    names = section.find_all("span", {"class": "ng-binding", "itemprop": "name"})
    streetAddress = section.find_all("span", {"class": "ng-binding", "itemprop": "streetAddress"})
    url = section.find_all("a", {"ng-href": True})
    
    
    for namesx,streetAddressx,urlx in zip(names,streetAddress,url):
        print(namesx.text)
        print(streetAddressx.text)
        print(urlx["ng-href"])
        
df.to_excel("resultados_elempleoxx.xlsx", index=False)
# Out:
# Abogado Sergio Diaz
# Prat 350 Ofi. 706
# /abogados
# Mauricio Caussade Goycoolea
# Av. Kennedy Lateral 5488, oficina 203
# /
# ABOGADOS R & R
# La Concepción 81 oficina 319
# /empresa/2000914/abogado-sergio-diaz
# Abogados MQM Valdivia
# alonso de benitez 1904
# /empresa/2000914/abogado-sergio-diaz
# BCK  ABOGADOSY CONTADORES AUDITORES
# Arlequi 263 piso 6
# /abogados/nacional
# BCG CONTADORES AUDITORES Y ABOGADOS
# Eizaguirre 450 piso 2 .
# /abogados/nacional
# BCM CONTADORES AUDITORES Y ABOGADOS
# Paseo Baquedano 1129
# /abogados/nacional
# abogados lex juicios
# San Antonio 19 oficina 1003
# /abogados/nacional
# Abogados Maipu
# General Ordoñez 30
# /abogados/nacional
# BCK  ABOGADOS Y CONTADORES AUDITORES
# Avenida Providencia 1208 Piso 16
# /abogados/nacional
# BCK CONTADORES AUDITORES Y ABOGADOS
# Avenida Bernardo Ohiggins 770 Piso 1
# /abogados/nacional
# Sarmiento & Núñez Abogados
# Prat 461, oficina 1606
# /abogados/nacional
# ABOGADOS TRIBUTARIOS SAN SEBASTIAN
# ...

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

url = "D:\Web_Scrapping\Prueba\offer1.html"
df = pd.DataFrame(columns=["Nombre","Direccion"])

with open(url, encoding="utf-8") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    section = soup.find("section", {"class": "template-search show-results col_main"})
    names = section.find_all("span", {"class": "ng-binding", "itemprop": "name"})
    streetAddress = section.find_all("span", {"class": "ng-binding", "itemprop": "streetAddress"})
    urls = section.find_all("a", attrs={"ng-href": True,"ng-click": True,"href": True,"itemprop":True})

    for name, streetAddress, url in zip(names, streetAddress, urls):
        #print(name.text)
        #print(streetAddress.text)
        #print("https://amarillas.emol.com{}".format(url["href"]))
        df = df.append({"Nombre": name.text, "Direccion": streetAddress.text, "URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
    
print(df)        
df.to_csv("resultados_elempleoxx.csv", index=False)
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\146292401.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Nombre": name.text, "Direccion": streetAddress.text, "URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\146292401.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"Nombre": name.text, "Direccion": streetAddress.text, "URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\146292401.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

df = pd.DataFrame(columns=["Nombre","Direccion", "URL"])

for i in range(1,3):
    url = "D:\Web_Scrapping\Prueba\offer{}.html".format(i)

    with open(url, encoding="utf-8") as fp:
        soup = BeautifulSoup(fp, 'html.parser')
        section = soup.find("section", {"class": "template-search show-results col_main"})
        names = section.find_all("span", {"class": "ng-binding", "itemprop": "name"})
        streetAddress = section.find_all("span", {"class": "ng-binding", "itemprop": "streetAddress"})
        urls = section.find_all("a", attrs={"ng-href": True,"ng-click": True,"href": True,"itemprop":True})

        for name, streetAddress, url in zip(names, streetAddress, urls):
            print(name.text)
            print(streetAddress.text)
            print("https://amarillas.emol.com{}".format(url["href"]))
            df = df.append({"Nombre": name.text, "Direccion": streetAddress.text, "URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)

df.to_excel("resultados_elempleoxx.xlsx", index=False)
# Out:
# Abogado Sergio Diaz
# Prat 350 Ofi. 706
# https://amarillas.emol.com/empresa/2000914/abogado-sergio-diaz
# Mauricio Caussade Goycoolea
# Av. Kennedy Lateral 5488, oficina 203
# https://amarillas.emol.com/empresa/525013/mauricio-caussade-goycoolea
# ABOGADOS R & R
# La Concepción 81 oficina 319
# https://amarillas.emol.com/empresa/2000127/abogados-r-r
# Abogados MQM Valdivia
# alonso de benitez 1904
# https://amarillas.emol.com/empresa/2001517/abogados-mqm-valdivia
# BCK  ABOGADOSY CONTADORES AUDITORES
# Arlequi 263 piso 6
# https://amarillas.emol.com/empresa/2001911/bck-abogadosy-contadores-auditores
# BCG CONTADORES AUDITORES Y ABOGADOS
# Eizaguirre 450 piso 2 .
# https://amarillas.emol.com/empresa/2001904/bcg-contadores-auditores-y-abogados
# BCM CONTADORES AUDITORES Y ABOGADOS
# Paseo Baquedano 1129
# https://amarillas.emol.com/empresa/2001909/bcm-contadores-auditores-y-abogados
# abogados lex juicios
# San Antonio 19 oficina 1003
# ...

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

url = "D:\Web_Scrapping\Prueba\offer1.html"
df = pd.DataFrame(columns=["Nombre","Direccion"])

with open(url, encoding="utf-8") as fp:
    soup = BeautifulSoup(fp, 'html.parser')
    a_element = soup.select_one("#search > section > article.ng-scope.item.premium_hit_bg.borde_naranja > h2 > a")
    if a_element:
        url = a_element["href"]
        print("https://amarillas.emol.com/{}".format(url))
        
df.to_excel("resultados_elempleoxx.xlsx", index=False)
# Out:
# https://amarillas.emol.com//empresa/2000914/abogado-sergio-diaz

# %% [markdown]
# # Recolectar todas las url de cada abogado

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import os

chromedriver = "D:/Web Scrapping/2/chromedriver.exe"
os.environ["webdriver.chrome.driver"] = chromedriver

# Inicializa el controlador de Chrome


def download_html_ct(pagina):
    driver = webdriver.Chrome(chromedriver)
    driver.get("https://amarillas.emol.com/abogados?p={}".format(pagina))
    time.sleep(5)
    with open(r'pagina{}.html'.format(pagina), 'w', encoding="utf-8") as f:
        f.write(driver.page_source)
    driver.quit()
try: 
    for i in range (3):
        download_html_ct(i)      
except:
    pass
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\2547158233.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# # Guardar las url de cada pagina y guardarlas

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

df = pd.DataFrame(columns=["URL"])

for i in range(0,2):
    url = "D:\Web_Scrapping\Prueba\pagina{}.html".format(i)

    with open(url, encoding="utf-8") as fp:
        soup = BeautifulSoup(fp, 'html.parser')
        section = soup.find("section", {"class": "template-search show-results col_main"})
        urls = section.find_all("a", attrs={"ng-href": True,"ng-click": True,"href": True,"itemprop":True})

        for url in urls:
            df = df.append({"URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)

df.to_excel("resultados_url.xlsx", index=False)
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\3153994491.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\3153994491.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\3153994491.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({"URL": "https://amarillas.emol.com{}".format(url["href"])}, ignore_index=True)
# ...

# %% [markdown]
# # Abrir cada url para leer telefonos

# %%
def download_html_ct(url,x):
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    time.sleep(5)
    with open(r'abogado{}.html'.format(x), 'w',encoding="utf-8") as f:
        f.write(driver.page_source)
    driver.quit()

df = pd.read_excel("resultados_url.xlsx")
urls = df["URL"].tolist()

x=0
try: 
    for url in urls:
        x=x+1
        download_html_ct(url,x)      
except:
    pass
# Out:
# C:\Users\Fankrit\AppData\Local\Temp\ipykernel_32748\2312885763.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# # Leer info de cada abogado

# %%
import glob
import pandas as pd
from bs4 import BeautifulSoup

df = pd.DataFrame(columns=["URL"])

for i in range(1,4):
    url = r"D:\Web_Scrapping\Prueba\abogado{}.html".format(i)

    with open(url, encoding="utf-8") as fp:
        soup = BeautifulSoup(fp, 'html.parser')
        info = soup.find("div", {"class": "f-nombre_empresa"})
        name = info.find("h1", {"itemprop": "name", "class": "ng-binding"}).text
        print(name)
# Out:
# Abogado Sergio Diaz
# Mauricio Caussade Goycoolea
# ABOGADOS R & R
